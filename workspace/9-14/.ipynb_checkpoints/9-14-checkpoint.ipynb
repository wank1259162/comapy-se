# %%
from __future__ import division
from numpy.random import randn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.rc('figure', figsize=(12, 5))
np.set_printoptions(precision=4)
# %pwd
plt.rcParams['font.sans-serif']=['SimHei']#中文标签

# %%
#path='./itchat_data.csv'

# %%
path='./2017MBA-N.csv'

# %%
columns = ['RemarkName', 'sex', 'births','NickName']

# %%
frame = pd.read_csv(path,encoding='utf-8')

# %%
fr1=frame.reindex(columns=['RemarkName','NickName','Sex','Province','City'])

# %%
fr1.groupby(['Province','City']).count()
# Out:
#                             RemarkName  NickName  Sex
# Province        City
# Queensland      Gold Coast           0         1    1
# South Australia Whyalla              0         1    1
# 内蒙古             包头                   0         1    1
# 北京              东城                   2        10   10
#                 丰台                   0        13   13
#                 大兴                   0         5    5
#                 延庆                   0         1    1
#                 房山                   0         2    2
#                 昌平                   1        11   11
#                 朝阳                   5        79   79
#                 海淀                   5        79   79
#                 石景山                  0         2    2
#                 西城                   2        20   20
#                 通州                   0         6    6
#                 门头沟                  0         1    1
#                 顺义                   0        10   10
# ...

# %%
#fr2=fr1.groupby(['Province','City']).count().unstack().plot(kind='bar',figsize=(10,5),stacked=True)

# %%
#plt.show()

# %%
fr1[fr1['Province'].isnull()].count()
# Out:
# RemarkName     5
# NickName      47
# Sex           47
# Province       0
# City           0
# dtype: int64
