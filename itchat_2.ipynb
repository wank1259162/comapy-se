# %%
#coding=utf8
import itchat
import math
import PIL.Image as Image
import os
from pandas import Series,DataFrame
import pandas as pd
import numpy as np
# Out:
# █

# %%
itchat.auto_login(hotReload=True)   #设置为自动 登录
# Out:
# Getting uuid of QR code.
# Downloading QR code.
# Please scan the QR code to log in.
# Please press confirm on your phone.
# Loading the contact, this may take a little while.
# Login successfully as MIKE

# %%
friends = itchat.get_friends(update=True)[0:]

# %%
maps=itchat.get_mps(update=True)[0:]

# %%
chatroms=itchat.get_chatrooms(update=True)[0:]

# %%
ff=DataFrame(friends)              #好友列表
fmaps=DataFrame(maps)              #公众号列表
fchatroms=DataFrame(chatroms)      #群聊列表

# %%
#将数据写入文件保存，编码格式设置为utf-8
fchatroms.to_csv('itchat_chatroms.csv',encoding='utf-8') 
fmaps.to_csv('itchat_maps.csv',encoding='utf-8')
ff.to_csv('itchat_data.csv',encoding='utf-8')

# %%
#fchatroms[:5]['MemberCount']

# %%
#fchatroms[:5]['UserName']

# %%
memberList = itchat.update_chatroom(chatroms[4]['UserName'], detailedMember=True) #memberList返回所有群聊成员

# %%
#dc=memberList.update()

# %%
memberList['MemberList']
# Out:
# <ContactList: [<ChatroomMember: {u'UserName': u'@dee0d088ac5b23d0c209a22c8dc812e3', u'City': u'', u'DisplayName': u'\u975e\u5168\u65e5\u5236-\u6881\u723d\U0001f36d-\u96c6\u4e2d\u73ed1\u73ed', u'UniFriend': 0, 'MemberList': <ContactList: []>, u'PYQuanPin': u'momo', u'RemarkPYInitial': u'', u'Sex': 2, u'AppAccountFlag': 0, u'VerifyFlag': 0, u'Province': u'', u'KeyWord': u'mom', u'RemarkName': u'', u'PYInitial': u'MM', u'IsOwner': 0, u'ChatRoomId': 0, u'HideInputBarFlag': 0, u'EncryChatRoomId': u'@57a56832a5a2930d6c2b846de60dfd26', u'AttrStatus': 200703, u'SnsFlag': 49, u'MemberCount': 0, u'OwnerUin': 0, u'Alias': u'', u'Signature': u'', u'ContactFlag': 0, u'NickName': u'\u672b\u672b', u'RemarkPYQuanPin': u'', u'HeadImgUrl': u'/cgi-bin/mmwebwx-bin/webwxgeticon?seq=0&username=@dee0d088ac5b23d0c209a22c8dc812e3&chatroomid=@57a56832a5a2930d6c2b846de60dfd26&skey=', u'Uin': 0, u'StarFriend': 0, u'Statues': 0}>, <ChatroomMember: {u'UserName': u'@2620eb581bbec01031cfe32230908a8c', u'City': u'\u4e30\u53f0', u'DisplayName': u'\u5f20\u7a00\u94a7-\u96c6\u4e2d\u4e8c\u73ed', u'UniFriend': 0, 'MemberList': <ContactList: []>, u'PYQuanPin': u'xijun', u'RemarkPYInitial': u'', u'Sex': 2, u'AppAccountFlag': 0, u'VerifyFlag': 0, u'Province': u'\u5317\u4eac', u'KeyWord': u'zha', u'RemarkName': u'', u'
d3b\u5728\u5f53\u4e0b \u7f05\u6000\u8fc7\u53bb', u'ContactFlag': 0, u'NickName': u'\u5446\u5446', u'RemarkPYQuanPin': u'', u'HeadImgUrl': u'/cgi-bin/mmwebwx-bin/webwxgeticon?seq=0&username=@75ed1630ad8268d12f37b5b379fc69a7&chatroomid=@57a56832a5a2930d6c2b846de60dfd26&skey=', u'Uin': 0, u'StarFriend': 0, u'Statues': 0}>, <ChatroomMember: {u'UserName': u'@aee228d20d0e7c8004b3b433d8e47a8bd5118174db093c9bf291de1e006e6559', u'City': u'\u6d77\u6dc0', u'DisplayName': u'\u975e\u5168\u ...

# %%
meb_fd21=DataFrame(
                   dict(memberList)['MemberList'],
                   #columns=['DisplayName','City','UserName','Sex','Signature'],
                   index=range(memberList['MemberCount'])
                )

# %%
meb_fd21.to_csv('123.csv',encoding='utf-8')

# %%
meb_fd=DataFrame(
                   dict(memberList)['MemberList'],
                   columns=['DisplayName','City','UserName','Sex','Signature'],
                   index=range(memberList['MemberCount'])
                )

# %%
#meb_fd.pivot_table(index=['City'])

# %%
meb_fd.head()
# Out:
#        DisplayName City                                           UserName  \
# 0  非全日制-梁爽🍭-集中班1班                       @dee0d088ac5b23d0c209a22c8dc812e3
# 1         张稀钧-集中二班   丰台                  @2620eb581bbec01031cfe32230908a8c
# 2    非全日制-李宗阳-周末3班   朝阳  @87a54b19c6a44831abe9fcc224923957e64e30c7da239...
# 3          全日制-郜晓卉   朝阳                  @75ed1630ad8268d12f37b5b379fc69a7
# 4         非全日制-徐国琳   海淀  @aee228d20d0e7c8004b3b433d8e47a8bd5118174db093...
#
#    Sex                                 Signature
# 0    2
# 1    2  Be slow to promise and quick to perform.
# 2    2                                 认真的人总会有收获
# 3    2                                 活在当下 缅怀过去
# 4    1                             高山流水，炊烟飘处是我家。

# %%
#meb_fd.pivot(columns=['City'],index=['UserName'])

# %%
#meb_fd.groupby(['City','Sex']).count()

# %%
#pd.pivot_table(meb_fd,columns=['City','Sex'])

# %%
#meb_fd['Signature']

# %%
num = 0

# %%
#for i in friends:
#     img = itchat.get_head_img(userName=u'@d96d99f58268df25ec619d2d240027c8')	
#     with open('./headImg1/'+str(num) + ".jpg",'wb') as f:
#	 f.write(img)
#	 f.close()
#	 num += 1

# %%
for i in range(memberList['MemberCount']):
              img = itchat.get_head_img(
                                         #userName=u'@fa11bfbf20ef31274032419974c19b40',
                                         userName=DataFrame(dict(memberList)['MemberList'])['UserName'][i],
                                         chatroomUserName=u'@@dc389348d554bea89c341bfd0697f340450fc2c06433834945db2336ad0f73bb'
                                       )
              with open('./headImg2/'+str(num) + ".jpg",'wb') as f: 
               f.write(img)
               f.close()
              num += 1

# %%
DataFrame(dict(memberList)['MemberList']).to_csv('itchat_room_data.csv',encoding='utf-8')
