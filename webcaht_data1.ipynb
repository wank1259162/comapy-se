# %%
#coding=utf8
import itchat
import math
import PIL.Image as Image
import os
from pandas import Series,DataFrame
import pandas as pd
import numpy as np

# %%
clo_name=['DisplayName','City','UserName','Sex','Signature']

# %%
df1=pd.read_csv('itchat_cywang.csv',header=None,names=clo_name)

# %%
df2=pd.read_csv('itchat_2017MBA.csv',header=None,names=clo_name)

# %%
df1.head()
# Out:
#      DisplayName  City                           UserName  Sex  \
# Num  DisplayName  City                           UserName  Sex
# 0            NaN   NaN  @15d189ba9025fb67d30792d2869adb3c    2
# 1         郭东-社科院    西城  @434ffcd1d2f10a48af33fd2917107dae    1
# 2            NaN   NaN  @2298202392c8f1dda7271a699186ee0e    1
# 3            NaN    赤峰  @a91e10181cf84d5bc0409557a1a68472    1
#
#                                              Signature
# Num                                          Signature
# 0    重情、守信、有礼、有节<span class="emoji emoji1f319"></span>
# 1                                             奔跑着 思考着
# 2                                          起风了，你追的上我吗？
# 3                                                  NaN

# %%
df2.head()
# Out:
#          DisplayName  City                                           UserName  \
# Num      DisplayName  City                                           UserName
# 0    非全日制-梁爽🍭-集中班1班   NaN                  @e66ada8d8519c8e693eadee3c1849f1c
# 1           张稀钧-集中二班    丰台                  @869626439ca5f62dbd797b651f4f21f3
# 2      非全日制-李宗阳-周末3班    朝阳  @bedc2631c98f60427740f35c00e572dd4f6c4e9b5e6bf...
# 3            全日制-郜晓卉    朝阳                  @d919db5464c240a60cbbb508e485833b
#
#      Sex                                 Signature
# Num  Sex                                 Signature
# 0      2                                       NaN
# 1      2  Be slow to promise and quick to perform.
# 2      2                                 认真的人总会有收获
# 3      2                                 活在当下 缅怀过去

# %%
#df2.rename(index=str,inplace=True)

# %%
#df2
# Out:
#          DisplayName  City                                           UserName  \
# Num      DisplayName  City                                           UserName
# 0    非全日制-梁爽🍭-集中班1班   NaN                  @e66ada8d8519c8e693eadee3c1849f1c
# 1           张稀钧-集中二班    丰台                  @869626439ca5f62dbd797b651f4f21f3
# 2      非全日制-李宗阳-周末3班    朝阳  @bedc2631c98f60427740f35c00e572dd4f6c4e9b5e6bf...
# 3            全日制-郜晓卉    朝阳                  @d919db5464c240a60cbbb508e485833b
# 4           非全日制-徐国琳    海淀  @cdd236a333e8054d9538bf16917c6762e7875e087bc09...
# 5       非全日制-朱贵祥-集中2    昌平  @0a8e4de69f8cc6975ab6e482ac5a82c6f258e5fa831a1...
# 6       非全日制-袁仟-周末3班    西城                  @aaa08dcbae7047c74d5fb280d15763b2
# 7     非全日制-范大健- 航空器材    顺义  @65f0d9e14ac392824ca76987b834d0d03eaa56d222b2e...
# 8       非全日制-陈嘉庚-集中1    西城  @cd78cbe50dfa37f35b128255574335769dbba74d68d88...
# 9              非全 郭源    海淀  @777bd5a417d7f4f4ba5796ffaf7bb3c3094704c78694b...
# ...

# %%
#df2['City'].fillna('BeiJing')

# %%
#df2.columns()

# %%
#df2.City.fillna('BK')
